# %%
import xml.etree.ElementTree as ET
tree = ET.parse('informatica_komahar.XML')
root = tree.getroot()

# %%
print(root)
print(root.tag, root.attrib)
# Out:
# <Element 'POWERMART' at 0x0000017CFCF1C540>
# POWERMART {'CREATION_DATE': '04/24/2023 15:09:24', 'REPOSITORY_VERSION': '184.93'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# REPOSITORY {'NAME': 'PowerCenterProd2', 'VERSION': '184', 'CODEPAGE': 'MS1252', 'DATABASETYPE': 'Microsoft SQL Server'}

# %%
root[0][0].attrib['NAME']
# Out:
# 'AgencyShared'

# %%
for folder in root.iter('FOLDER'):
    print(folder.attrib)
# Out:
# {'NAME': 'AgencyShared', 'GROUP': '', 'OWNER': 'Administrator', 'SHARED': 'SHARED', 'DESCRIPTION': '', 'PERMISSIONS': 'rwx------', 'UUID': 'a2c28a96-3bd7-4911-a28e-45850c9e195d'}
# {'NAME': 'AgencyDataMart', 'GROUP': '', 'OWNER': 'Administrator', 'SHARED': 'NOTSHARED', 'DESCRIPTION': '', 'PERMISSIONS': 'rwx------', 'UUID': '05dccfc6-e007-4b2e-bb03-e60ee90b2330'}
# {'NAME': 'aaaWBMIShared', 'GROUP': '', 'OWNER': 'Administrator', 'SHARED': 'SHARED', 'DESCRIPTION': '', 'PERMISSIONS': 'rwx------', 'UUID': '5b9756f6-b675-4c3c-a3f3-6dfaf9123095'}

# %%
no_of_folders = 0
total_no_mappings = 0
for i, folder in enumerate(root.iter('FOLDER')):
    no_of_folders += 1
    
    no_of_mapping = 0
    for mapping in folder.iter('MAPPING'): no_of_mapping +=  1
    total_no_mappings += no_of_mapping
    print(f"No. of mappings in Folder {i} : {no_of_mapping}")

print(f"\nNo. of Folders = {no_of_folders}")
print(f"Total no. of Mappings = {total_no_mappings}")
# Out:
# No. of mappings in Folder 0 : 0
# No. of mappings in Folder 1 : 7
# No. of mappings in Folder 2 : 3
#
# No. of Folders = 3
# Total no. of Mappings = 10

# %%
no_of_folders = len(root.findall('.//FOLDER'))
total_no_mappings = sum(len(folder.findall('.//MAPPING')) for folder in root.findall('.//FOLDER'))

for i, folder in enumerate(root.iter('FOLDER')):
    print(f"No. of mappings in Folder {i} : {len(folder.findall('.//MAPPING'))}")

print(f"\nNo. of Folders = {no_of_folders}")
print(f"Total no. of Mappings = {total_no_mappings}")
# Out:
# No. of mappings in Folder 0 : 0
# No. of mappings in Folder 1 : 7
# No. of mappings in Folder 2 : 3
#
# No. of Folders = 3
# Total no. of Mappings = 10

# %%
model_basic = {}

for folder in root.iter('FOLDER'):
    name = folder.get('NAME')

    for mapping in folder.iter('MAPPING'):
        mapping_name = mapping.get('NAME')
        tasks = {task.get('NAME'): {'name': task.get('NAME'), 'task_type': task.get('TRANSFORMATION_TYPE'), 'transformation_name': task.get('TRANSFORMATION_NAME')} for task in mapping.iter('INSTANCE')}
        model_basic[mapping_name] = {'name': mapping_name, 'parent_folder': name, 'tasks': tasks}

print(model_basic)
# Out:
# {'m_AGY_DM_LOAD_AgencyRelationshipCurrent': {'name': 'm_AGY_DM_LOAD_AgencyRelationshipCurrent', 'parent_folder': 'AgencyDataMart', 'tasks': {'AgencyRelationshipCurrent': {'name': 'AgencyRelationshipCurrent', 'task_type': 'Target Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipCurrent'}, 'AgencyRelationshipDim': {'name': 'AgencyRelationshipDim', 'task_type': 'Source Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim'}, 'SQ_Shortcut_to_AgencyRelationshipDim': {'name': 'SQ_Shortcut_to_AgencyRelationshipDim', 'task_type': 'Source Qualifier', 'transformation_name': 'SQ_Shortcut_to_AgencyRelationshipDim'}, 'EXP_Standalone': {'name': 'EXP_Standalone', 'task_type': 'Expression', 'transformation_name': 'EXP_Standalone'}}}, 'm_AGY_DM_LOAD_AgencyRelationshipDim': {'name': 'm_AGY_DM_LOAD_AgencyRelationshipDim', 'parent_folder': 'AgencyDataMart', 'tasks': {'AgencyRelationshipDim_Insert': {'name': 'AgencyRelationshipDim_Insert', 'task_type': 'Target Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim'}, 'AgencyRelationshipDim_Updates': {'name': 'AgencyRelationshipDim_Updates', 'task_type': 'Target Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim'}, 'LKP_Agencyrelationshipdim': {'name': 'LKP_Agencyrelationshipdim', 'task_type': 'Lookup Procedure', 'transformation_name': 'LKP_Agencyrelationshipdim'}, 'UPD_OldRecords': {'name': 'UPD_OldRecords', 'task_type': 'Update Strategy', 'transformation_name': 'UPD_OldRecords'}, 'SQ_AgencyRelationship': {'name': 'SQ_AgencyRelationship', 'task_type': 'Source Qualifier', 'transformation_name': 'SQ_AgencyRelationship'}, 'EXP_Detect_Changes': {'name': 'EXP_Detect_Changes', 'task_type': 'Expression', 'transformation_name': 'EXP_Detect_Changes'}, 'SQ_AgencyRelationshipDim': {'name': 'SQ_AgencyRelationshipDim', 'task_type': 'Source Qualifier', 'transformation_name': 'SQ_AgencyRelationshipDim'}, 'EXP_AgencyRelationship': {'name': 'EXP_AgencyRelationship', 'task_type': 'Expression', 'transformation_name': 'EXP_AgencyRelationship'}, 'EXP_Assign_AKID': {'name': 'EXP_Assign_AKID', 'task_type': 'Expression', 'transformation_name': 'EXP_Assign_AKID'}, 'FLT_Agencyrelationshipdate': {'name': 'FLT_Agencyrelationshipdate', 'task_type': 'Filter', 'transformation_name': 'FLT_Agencyrelationshipdate'}, 'EXP_Agencyrelationshipdates': {'name': 'EXP_Agencyrelationshipdates', 'task_type': 'Expression', 'transformation_name': 'EXP_Agencyrelationshipdates'}, 'FLT_Agencyrelationshipdim': {'name': 'FLT_Agencyrelationshipdim', 'task_type': 'Filter', 'transformation_name': 'FLT_Agencyrelationshipdim'}, 'EXP_GetAKIDs': {'name': 'EXP_GetAKIDs', 'task_type': 'Expression', 'transformation_name': 'EXP_GetAKIDs'}, 'AgencyRelationshipDim': {'name': 'AgencyRelationshipDim', 'task_type': 'Source Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim'}, 'AgencyRelationship': {'name': 'AgencyRelationship', 'task_type': 'Source Definition', 'transformation_name': 'AgencyRelationship'}, 'LKP_GetAgencyCodes': {'name': 'LKP_GetAgencyCodes', 'task_type': 'Lookup Procedure', 'transformation_name': 'LKP_GetAgencyCodes'}}}, 'm_AGY_DM_LOAD_AgencySilverCircleTierDim': {'name': 'm_AGY_DM_LOAD_AgencySilverCircleTierDim', 'parent_folder': 'AgencyDataMart', 'tasks': {'AgencySilverCircleTierDim': {'name': 'AgencySilverCircleTierDim', 'task_type': 'Target Definition', 'transformation_name': 'AgencySilverCircleTierDim'}, 'AgencySilverCircleTier': {'name': 'AgencySilverCircleTier', 'task_type': 'Source Definition', 'transformation_name': 'AgencySilverCircleTier'}, 'SQ_AgencySilverCircleTier': {'name': 'SQ_AgencySilverCircleTier', 'task_type': 'Source Qualifier', 'transformation_name': 'SQ_AgencySilverCircleTier'}, 'EXPTRANS': {'name': 'EXPTRANS', 'task_type': 'Expression', 'transformation_name': 'EXPTRANS'}}}, 'm_AGY_DM_Load_UnderwritingDivisionDim': {'name': 'm_AGY_DM_Load_UnderwritingDivisionDim', 'parent_folder': 'AgencyDataMart', 'tasks': {'TGT_UnderwritingDivisionD ...

# %%
import json
print(json.dumps(model_basic, indent=4))
# Out:
# {
#     "m_AGY_DM_LOAD_AgencyRelationshipCurrent": {
#         "name": "m_AGY_DM_LOAD_AgencyRelationshipCurrent",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "AgencyRelationshipCurrent": {
#                 "name": "AgencyRelationshipCurrent",
#                 "task_type": "Target Definition",
#                 "transformation_name": "Shortcut_to_AgencyRelationshipCurrent"
#             },
#             "AgencyRelationshipDim": {
#                 "name": "AgencyRelationshipDim",
#                 "task_type": "Source Definition",
#                 "transformation_name": "Shortcut_to_AgencyRelationshipDim"
#             },
#             "SQ_Shortcut_to_AgencyRelationshipDim": {
#                 "name": "SQ_Shortcut_to_AgencyRelationshipDim",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_Shortcut_to_AgencyRelationshipDim"
#             },
#             "EXP_Standalone": {
#                 "name": "EXP_Standalone",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_Standalone"
#             }
#         }
#     },
#     "m_AGY_DM_LOAD_AgencyRelationshipDim": {
#         "name": "m_AGY_DM_LOAD_AgencyRelationshipDim",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "AgencyRelationshipDim_Insert": {
#                 "name": "AgencyRelationshipDim_Insert",
#                 "task_type": "Target Definition",
#                 "transformation_name": "Shortcut_to_AgencyRelationshipDim"
#             },
#             "AgencyRelationshipDim_Updates": {
#                 "name": "AgencyRelationshipDim_Updates",
#                 "task_type": "Target Definition",
#                 "transformation_name": "Shortcut_to_AgencyRelationshipDim"
#             },
#             "LKP_Agencyrelationshipdim": {
#                 "name": "LKP_Agencyrelationshipdim",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_Agencyrelationshipdim"
#             },
#             "UPD_OldRecords": {
#                 "name": "UPD_OldRecords",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_OldRecords"
#             },
#             "SQ_AgencyRelationship": {
#                 "name": "SQ_AgencyRelationship",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_AgencyRelationship"
#             },
#             "EXP_Detect_Changes": {
#                 "name": "EXP_Detect_Changes",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_Detect_Changes"
#             },
#             "SQ_AgencyRelationshipDim": {
#                 "name": "SQ_AgencyRelationshipDim",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_AgencyRelationshipDim"
#             },
#             "EXP_AgencyRelationship": {
#                 "name": "EXP_AgencyRelationship",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_AgencyRelationship"
#             },
#             "EXP_Assign_AKID": {
#                 "name": "EXP_Assign_AKID",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_Assign_AKID"
#             },
#             "FLT_Agencyrelationshipdate": {
#                 "name": "FLT_Agencyrelationshipdate",
#                 "task_type": "Filter",
#                 "transformation_name": "FLT_Agencyrelationshipdate"
#             },
#             "EXP_Agencyrelationshipdates": {
#                 "name": "EXP_Agencyrelationshipdates",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_Agencyrelationshipdates"
#             },
#             "FLT_Agencyrelationshipdim": {
#                 "name": "FLT_Agencyrelationshipdim",
#                 "task_type": "Filter",
#                 "transformation_name": "FLT_Agencyrelationshipdim"
#             },
#             "EXP_GetAKIDs": {
#                 "name": "EXP_GetAKIDs",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_GetAKIDs"
#             },
#             "AgencyRelationshipDim": {
#                 "name": "AgencyRelationshipDim",
#                 "task_type": "Source Definition",
#                 "transformation_name": "Shortcut_to_AgencyRelationshipDim"
#             },
#             "AgencyRelationship": {
#                 "name": "AgencyRelationship",
#                 "task_type": "Source Definition",
#                 "transformation_name": "AgencyRelationship"
#             },
#             "LKP_GetAgencyCodes": {
#                 "name": "LKP_GetAgencyCodes",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_GetAgencyCodes"
#             }
#         }
#     },
#     "m_AGY_DM_LOAD_AgencySilverCircleTierDim": {
#         "name": "m_AGY_DM_LOAD_AgencySilverCircleTierDim",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "AgencySilverCircleTierDim": {
#                 "name": "AgencySilverCircleTierDim",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencySilverCircleTierDim"
#             },
#             "AgencySilverCircleTier": {
#                 "name": "AgencySilverCircleTier",
#                 "task_type": "Source Definition",
#                 "transformation_name": "AgencySilverCircleTier"
#             },
#             "SQ_AgencySilverCircleTier": {
#                 "name": "SQ_AgencySilverCircleTier",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_AgencySilverCircleTier"
#             },
#             "EXPTRANS": {
#                 "name": "EXPTRANS",
#                 "task_type": "Expression",
#                 "transformation_name": "EXPTRANS"
#             }
#         }
#     },
#     "m_AGY_DM_Load_UnderwritingDivisionDim": {
#         "name": "m_AGY_DM_Load_UnderwritingDivisionDim",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "TGT_UnderwritingDivisionDim_Update": {
#                 "name": "TGT_UnderwritingDivisionDim_Update",
#                 "task_type": "Target Definition",
#                 "transformation_name": "UnderwritingDivisionDim"
#             },
#             "TGT_UnderwritingDivisionDim_Insert": {
#                 "name": "TGT_UnderwritingDivisionDim_Insert",
#                 "task_type": "Target Definition",
#                 "transformation_name": "UnderwritingDivisionDim"
#             },
#             "UnderwritingAssociate": {
#                 "name": "UnderwritingAssociate",
#                 "task_type": "Source Definition",
#                 "transformation_name": "UnderwritingAssociate"
#             },
#             "LKP_UnderwritingRegion": {
#                 "name": "LKP_UnderwritingRegion",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_UnderwritingRegion"
#             },
#             "LKP_Existing": {
#                 "name": "LKP_Existing",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_Existing"
#             },
#             "LKP_UWManager": {
#                 "name": "LKP_UWManager",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_UWManager"
#             },
#             "UPD_InsertNew": {
#                 "name": "UPD_InsertNew",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_InsertNew"
#             },
#             "EXP_CleanupUWDivisionDetails": {
#                 "name": "EXP_CleanupUWDivisionDetails",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CleanupUWDivisionDetails"
#             },
#             "EXP_CheckForChange": {
#                 "name": "EXP_CheckForChange",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CheckForChange"
#             },
#             "SQ_UnderwritingAssociate": {
#                 "name": "SQ_UnderwritingAssociate",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_UnderwritingAssociate"
#             },
#             "UPD_UpdateExisting": {
#                 "name": "UPD_UpdateExisting",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_UpdateExisting"
#             },
#             "RTR_InsertUpdateOrExpire": {
#                 "name": "RTR_InsertUpdateOrExpire",
#                 "task_type": "Router",
#                 "transformation_name": "RTR_InsertUpdateOrExpire"
#             }
#         }
#     },
#     "m_AGY_DM_Load_AgencyEmployeeDim": {
#         "name": "m_AGY_DM_Load_AgencyEmployeeDim",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "TGT_AgencyEmployeeDim_Expire": {
#                 "name": "TGT_AgencyEmployeeDim_Expire",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyEmployeeDim"
#             },
#             "TGT_AgencyEmployeeDim_Insert": {
#                 "name": "TGT_AgencyEmployeeDim_Insert",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyEmployeeDim"
#             },
#             "TGT_AgencyEmployeeDim_Updates": {
#                 "name": "TGT_AgencyEmployeeDim_Updates",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyEmployeeDim"
#             },
#             "AgencyEmployee": {
#                 "name": "AgencyEmployee",
#                 "task_type": "Source Definition",
#                 "transformation_name": "AgencyEmployee"
#             },
#             "SQ_AgencyEmployee": {
#                 "name": "SQ_AgencyEmployee",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_AgencyEmployee"
#             },
#             "EXP_CollectData": {
#                 "name": "EXP_CollectData",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CollectData"
#             },
#             "EXP_CheckForChange": {
#                 "name": "EXP_CheckForChange",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CheckForChange"
#             },
#             "UPD_ExpireOld": {
#                 "name": "UPD_ExpireOld",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_ExpireOld"
#             },
#             "RTR_InsertUpdateOrExpire": {
#                 "name": "RTR_InsertUpdateOrExpire",
#                 "task_type": "Router",
#                 "transformation_name": "RTR_InsertUpdateOrExpire"
#             },
#             "UPD_InsertNew": {
#                 "name": "UPD_InsertNew",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_InsertNew"
#             },
#             "UPD_Updates": {
#                 "name": "UPD_Updates",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_Updates"
#             },
#             "LKP_AgencyCode": {
#                 "name": "LKP_AgencyCode",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_AgencyCode"
#             },
#             "LKP_Existing": {
#                 "name": "LKP_Existing",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_Existing"
#             }
#         }
#     },
#     "m_AGY_DM_Load_SalesDivisionDim": {
#         "name": "m_AGY_DM_Load_SalesDivisionDim",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "TGT_SalesDivisionDim_Inserts": {
#                 "name": "TGT_SalesDivisionDim_Inserts",
#                 "task_type": "Target Definition",
#                 "transformation_name": "SalesDivisionDim"
#             },
#             "TGT_SalesDivisionDim_Updates": {
#                 "name": "TGT_SalesDivisionDim_Updates",
#                 "task_type": "Target Definition",
#                 "transformation_name": "SalesDivisionDim"
#             },
#             "UPD_InsertNew": {
#                 "name": "UPD_InsertNew",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_InsertNew"
#             },
#             "Agency_V2": {
#                 "name": "Agency_V2",
#                 "task_type": "Source Definition",
#                 "transformation_name": "Agency_V2"
#             },
#             "RegionalSalesManager": {
#                 "name": "RegionalSalesManager",
#                 "task_type": "Source Definition",
#                 "transformation_name": "RegionalSalesManager"
#             },
#             "UPD_UpdateExisting": {
#                 "name": "UPD_UpdateExisting",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_UpdateExisting"
#             },
#             "LKP_Existing": {
#                 "name": "LKP_Existing",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_Existing"
#             },
#             "EXP_GetCleanup": {
#                 "name": "EXP_GetCleanup",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_GetCleanup"
#             },
#             "SQ_JoinSalesDivisionSources": {
#                 "name": "SQ_JoinSalesDivisionSources",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_JoinSalesDivisionSources"
#             },
#             "EXP_CollectData": {
#                 "name": "EXP_CollectData",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CollectData"
#             },
#             "RTR_InsertUpdate": {
#                 "name": "RTR_InsertUpdate",
#                 "task_type": "Router",
#                 "transformation_name": "RTR_InsertUpdate"
#             },
#             "SalesTerritory": {
#                 "name": "SalesTerritory",
#                 "task_type": "Source Definition",
#                 "transformation_name": "SalesTerritory"
#             },
#             "LKP_SalesDirector": {
#                 "name": "LKP_SalesDirector",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_SalesDirector"
#             },
#             "EXP_CheckForChange": {
#                 "name": "EXP_CheckForChange",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CheckForChange"
#             }
#         }
#     },
#     "m_AGY_DM_Load_AgencyDim_v3": {
#         "name": "m_AGY_DM_Load_AgencyDim_v3",
#         "parent_folder": "AgencyDataMart",
#         "tasks": {
#             "AgencyDim_UpdateHistory": {
#                 "name": "AgencyDim_UpdateHistory",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyDim"
#             },
#             "TGT_AgencyDim_InsertNew": {
#                 "name": "TGT_AgencyDim_InsertNew",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyDim"
#             },
#             "TGT_AgencyDim_UpdateExisting": {
#                 "name": "TGT_AgencyDim_UpdateExisting",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyDim"
#             },
#             "TGT_AgencyDim_ExpireOld": {
#                 "name": "TGT_AgencyDim_ExpireOld",
#                 "task_type": "Target Definition",
#                 "transformation_name": "AgencyDim"
#             },
#             "LKP_PhysicalAddress": {
#                 "name": "LKP_PhysicalAddress",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_PhysicalAddress"
#             },
#             "LKP_AgencyDim_ExistingData": {
#                 "name": "LKP_AgencyDim_ExistingData",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_AgencyDim_ExistingData"
#             },
#             "LKP_Agency_V2": {
#                 "name": "LKP_Agency_V2",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_Agency_V2"
#             },
#             "UPD_AgencyDim_SalesDivisionDimId": {
#                 "name": "UPD_AgencyDim_SalesDivisionDimId",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_AgencyDim_SalesDivisionDimId"
#             },
#             "LKP_SalesDivisionDim": {
#                 "name": "LKP_SalesDivisionDim",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_SalesDivisionDim"
#             },
#             "Agency_V2": {
#                 "name": "Agency_V2",
#                 "task_type": "Source Definition",
#                 "transformation_name": "Agency_V2"
#             },
#             "LKP_RegionalSalesManager": {
#                 "name": "LKP_RegionalSalesManager",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_RegionalSalesManager"
#             },
#             "EXP_CheckForChange": {
#                 "name": "EXP_CheckForChange",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CheckForChange"
#             },
#             "LKP_MailingAddress": {
#                 "name": "LKP_MailingAddress",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_MailingAddress"
#             },
#             "SQ_Agency_SalesDivisionDim": {
#                 "name": "SQ_Agency_SalesDivisionDim",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_Agency_SalesDivisionDim"
#             },
#             "LKP_LegalParent_deleted": {
#                 "name": "LKP_LegalParent_deleted",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_LegalParent_deleted"
#             },
#             "LKP_LegalParent": {
#                 "name": "LKP_LegalParent",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_LegalParent"
#             },
#             "EXP_CleanupData": {
#                 "name": "EXP_CleanupData",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_CleanupData"
#             },
#             "UPD_ExpireOld": {
#                 "name": "UPD_ExpireOld",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_ExpireOld"
#             },
#             "RTR_InsertUpdateOrExpire": {
#                 "name": "RTR_InsertUpdateOrExpire",
#                 "task_type": "Router",
#                 "transformation_name": "RTR_InsertUpdateOrExpire"
#             },
#             "UPD_Inserts": {
#                 "name": "UPD_Inserts",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_Inserts"
#             },
#             "UPD_Updates": {
#                 "name": "UPD_Updates",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_Updates"
#             },
#             "SQ_Agency_V2": {
#                 "name": "SQ_Agency_V2",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_Agency_V2"
#             }
#         }
#     },
#     "m_Do_PostBatch": {
#         "name": "m_Do_PostBatch",
#         "parent_folder": "aaaWBMIShared",
#         "tasks": {
#             "wbmi_session_control_run_EXPIRE": {
#                 "name": "wbmi_session_control_run_EXPIRE",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_session_control_run"
#             },
#             "wbmi_batch_control_run_EXPIRE": {
#                 "name": "wbmi_batch_control_run_EXPIRE",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_batch_control_run"
#             },
#             "wbmi_batch_control": {
#                 "name": "wbmi_batch_control",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_batch_control"
#             },
#             "EXP_session_control_run": {
#                 "name": "EXP_session_control_run",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_session_control_run"
#             },
#             "UPD_batch_control_run": {
#                 "name": "UPD_batch_control_run",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_batch_control_run"
#             },
#             "EXP_batch_control_run": {
#                 "name": "EXP_batch_control_run",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_batch_control_run"
#             },
#             "LKP_REP_SESS_LOG": {
#                 "name": "LKP_REP_SESS_LOG",
#                 "task_type": "Lookup Procedure",
#                 "transformation_name": "LKP_REP_SESS_LOG"
#             },
#             "UPD_session_control_run": {
#                 "name": "UPD_session_control_run",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_session_control_run"
#             },
#             "SQ_wbmi_batch_control_run_EXPIRE": {
#                 "name": "SQ_wbmi_batch_control_run_EXPIRE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_batch_control_run_EXPIRE"
#             },
#             "SQ_wbmi_session_control_run_EXPIRE": {
#                 "name": "SQ_wbmi_session_control_run_EXPIRE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_session_control_run_EXPIRE"
#             },
#             "wbmi_session_control_run": {
#                 "name": "wbmi_session_control_run",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_session_control_run"
#             },
#             "wbmi_batch_control_run": {
#                 "name": "wbmi_batch_control_run",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_batch_control_run"
#             }
#         }
#     },
#     "m_Do_PreBatch": {
#         "name": "m_Do_PreBatch",
#         "parent_folder": "aaaWBMIShared",
#         "tasks": {
#             "Batch_Name": {
#                 "name": "Batch_Name",
#                 "task_type": "Target Definition",
#                 "transformation_name": "Batch_Name_Parm"
#             },
#             "wbmi_session_control_INCREMENT_SEL_START_END_TS": {
#                 "name": "wbmi_session_control_INCREMENT_SEL_START_END_TS",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_session_control"
#             },
#             "wbmi_session_control_run_EXPIRE": {
#                 "name": "wbmi_session_control_run_EXPIRE",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_session_control_run"
#             },
#             "wbmi_batch_control_run_EXPIRE": {
#                 "name": "wbmi_batch_control_run_EXPIRE",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_batch_control_run"
#             },
#             "wbmi_batch_control_run_INITIALIZE_NEW_BATCH": {
#                 "name": "wbmi_batch_control_run_INITIALIZE_NEW_BATCH",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_batch_control_run"
#             },
#             "wbmi_session_control_run_INITIALIZE_SESSIONS": {
#                 "name": "wbmi_session_control_run_INITIALIZE_SESSIONS",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_session_control_run"
#             },
#             "EXP_wbmi_batch_control_imitialize_source": {
#                 "name": "EXP_wbmi_batch_control_imitialize_source",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_wbmi_batch_control_imitialize_source"
#             },
#             "SQ_wbmi_batch_control_INITIALIZE_NEW_BATCH": {
#                 "name": "SQ_wbmi_batch_control_INITIALIZE_NEW_BATCH",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_batch_control_INITIALIZE_NEW_BATCH"
#             },
#             "SQ_wbmi_session_control_run_EXPIRE": {
#                 "name": "SQ_wbmi_session_control_run_EXPIRE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_session_control_run_EXPIRE"
#             },
#             "UPD_wbmi_session_control": {
#                 "name": "UPD_wbmi_session_control",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_wbmi_session_control"
#             },
#             "UPD_wbmi_session_control_run_initialize": {
#                 "name": "UPD_wbmi_session_control_run_initialize",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_wbmi_session_control_run_initialize"
#             },
#             "EXP_wbmi_session_control": {
#                 "name": "EXP_wbmi_session_control",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_wbmi_session_control"
#             },
#             "EXP_session_control": {
#                 "name": "EXP_session_control",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_session_control"
#             },
#             "EXP_out_Parm_file": {
#                 "name": "EXP_out_Parm_file",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_out_Parm_file"
#             },
#             "UPD_wbmi_session_control_run": {
#                 "name": "UPD_wbmi_session_control_run",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_wbmi_session_control_run"
#             },
#             "EXP_wbmi_session_control_run_initialize": {
#                 "name": "EXP_wbmi_session_control_run_initialize",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_wbmi_session_control_run_initialize"
#             },
#             "SQ_wbmi_session_control_INCREMENT_SEL_START_END_TS": {
#                 "name": "SQ_wbmi_session_control_INCREMENT_SEL_START_END_TS",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_session_control_INCREMENT_SEL_START_END_TS"
#             },
#             "wbmi_session_control_run": {
#                 "name": "wbmi_session_control_run",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_session_control_run"
#             },
#             "wbmi_session_control_run3": {
#                 "name": "wbmi_session_control_run3",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_session_control_run"
#             },
#             "wbmi_batch_control_run": {
#                 "name": "wbmi_batch_control_run",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_batch_control_run"
#             },
#             "wbmi_batch_control": {
#                 "name": "wbmi_batch_control",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_batch_control"
#             },
#             "wbmi_session_control": {
#                 "name": "wbmi_session_control",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_session_control"
#             },
#             "wbmi_audit_control_run": {
#                 "name": "wbmi_audit_control_run",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_audit_control_run"
#             },
#             "UPD_wbmi_batch_control_run_initialize": {
#                 "name": "UPD_wbmi_batch_control_run_initialize",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_wbmi_batch_control_run_initialize"
#             },
#             "SQ_wbmi_session_control_INITIALIZE": {
#                 "name": "SQ_wbmi_session_control_INITIALIZE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_session_control_INITIALIZE"
#             },
#             "SQ_wbmi_batch_control_run_EXPIRE": {
#                 "name": "SQ_wbmi_batch_control_run_EXPIRE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_batch_control_run_EXPIRE"
#             },
#             "UPD_wbmi_batch_control_run": {
#                 "name": "UPD_wbmi_batch_control_run",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_wbmi_batch_control_run"
#             },
#             "EXP_wbmi_batch_control_run": {
#                 "name": "EXP_wbmi_batch_control_run",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_wbmi_batch_control_run"
#             },
#             "SQ_wbmi_session_control_run_PARM_FILE": {
#                 "name": "SQ_wbmi_session_control_run_PARM_FILE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_session_control_run_PARM_FILE"
#             }
#         }
#     },
#     "m_Do_PostAudit": {
#         "name": "m_Do_PostAudit",
#         "parent_folder": "aaaWBMIShared",
#         "tasks": {
#             "wbmi_audit_control_run_EXPIRE": {
#                 "name": "wbmi_audit_control_run_EXPIRE",
#                 "task_type": "Target Definition",
#                 "transformation_name": "wbmi_audit_control_run"
#             },
#             "EXP_audit_control_run": {
#                 "name": "EXP_audit_control_run",
#                 "task_type": "Expression",
#                 "transformation_name": "EXP_audit_control_run"
#             },
#             "UPD_wbmi_audit_control_run": {
#                 "name": "UPD_wbmi_audit_control_run",
#                 "task_type": "Update Strategy",
#                 "transformation_name": "UPD_wbmi_audit_control_run"
#             },
#             "wbmi_audit_control_run1": {
#                 "name": "wbmi_audit_control_run1",
#                 "task_type": "Source Definition",
#                 "transformation_name": "wbmi_audit_control_run"
#             },
#             "SQ_wbmi_audit_control_run_EXPIRE": {
#                 "name": "SQ_wbmi_audit_control_run_EXPIRE",
#                 "task_type": "Source Qualifier",
#                 "transformation_name": "SQ_wbmi_audit_control_run_EXPIRE"
#             }
#         }
#     }
# }

# %%
# Serializing json
json_object = json.dumps(model_basic, indent=4)
 
# Writing to sample.json
with open("model_basic.json", "w") as outfile:
    outfile.write(json_object)

# %% [markdown]
# ## add Transformation Fields in Tasks

# %%
model_basic = {}

for folder in root.iter('FOLDER'):
    folder_name = folder.get('NAME')

    for mapping in folder.iter('MAPPING'):
        mapping_name = mapping.get('NAME')
        tasks = {}
        transformations = {trans.get('NAME'): [{'name': field.get('NAME'), 'data_type': field.get('DATATYPE')} for field in trans.iter('TRANSFORMFIELD')] for trans in mapping.iter('TRANSFORMATION')}
        
        for task in mapping.iter('INSTANCE'):
            task_name = task.get('NAME')
            task_type = task.get('TRANSFORMATION_TYPE')
            trans_name = task.get('TRANSFORMATION_NAME')
            fields = transformations.get(trans_name, [])

            tasks[task_name] = {'name': task_name, 'task_type': task_type, 'transformation_name': trans_name, 'fields': fields}

        model_basic[mapping_name] = {'name': mapping_name, 'parent_folder': folder_name, 'tasks': tasks}

print(model_basic)
# Out:
# {'m_AGY_DM_LOAD_AgencyRelationshipCurrent': {'name': 'm_AGY_DM_LOAD_AgencyRelationshipCurrent', 'parent_folder': 'AgencyDataMart', 'tasks': {'AgencyRelationshipCurrent': {'name': 'AgencyRelationshipCurrent', 'task_type': 'Target Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipCurrent', 'fields': []}, 'AgencyRelationshipDim': {'name': 'AgencyRelationshipDim', 'task_type': 'Source Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim', 'fields': []}, 'SQ_Shortcut_to_AgencyRelationshipDim': {'name': 'SQ_Shortcut_to_AgencyRelationshipDim', 'task_type': 'Source Qualifier', 'transformation_name': 'SQ_Shortcut_to_AgencyRelationshipDim', 'fields': [{'name': 'EDWAgencyAKId', 'data_type': 'integer'}, {'name': 'EDWLegalPrimaryAgencyAKId', 'data_type': 'integer'}, {'name': 'AgencyRelationshipEffectiveDate', 'data_type': 'date/time'}, {'name': 'AgencyRelationshipExpirationDate', 'data_type': 'date/time'}]}, 'EXP_Standalone': {'name': 'EXP_Standalone', 'task_type': 'Expression', 'transformation_name': 'EXP_Standalone', 'fields': [{'name': 'EDWAgencyAKId', 'data_type': 'integer'}, {'name': 'EDWLegalPrimaryAgencyAKId', 'data_type': 'integer'}, {'name': 'AgencyRelationshipEffectiveDate', 'data_type': 'date/time'}, {'name': 'AgencyRelationshipExpirationDate', 'data_type': 'date/time'}, {'name': 'o_AuditID', 'data_type': 'integer'}, {'name': 'o_CreateDate', 'data_type': 'date/time'}, {'name': 'o_ModifiedDate', 'data_type': 'date/time'}]}}}, 'm_AGY_DM_LOAD_AgencyRelationshipDim': {'name': 'm_AGY_DM_LOAD_AgencyRelationshipDim', 'parent_folder': 'AgencyDataMart', 'tasks': {'AgencyRelationshipDim_Insert': {'name': 'AgencyRelationshipDim_Insert', 'task_type': 'Target Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim', 'fields': []}, 'AgencyRelationshipDim_Updates': {'name': 'AgencyRelationshipDim_Updates', 'task_type': 'Target Definition', 'transformation_name': 'Shortcut_to_AgencyRelationshipDim', 'fields': []}, 'LKP_Agencyrelationshipdim': {'name': 'LKP_Agencyrelationshipdim', 'task_type': 'Lookup Procedure', 'transformation_name': 'LKP_Agencyrelationshipdim', 'fields': [{'name': 'AgencyRelationshipDimId', 'data_type': 'integer'}, {'name': 'CurrentSnapshotFlag', 'data_type': 'string'}, {'name': 'AuditID', 'data_type': 'integer'}, {'name': 'EffectiveDate', 'data_type': 'date/time'}, {'name': 'ExpirationDate', 'data_type': 'date/time'}, {'name': 'CreateDate', 'data_type': 'date/time'}, {'name': 'ModifiedDate', 'data_type': 'date/time'}, {'name': 'EDWAgencyAKId', 'data_type': 'integer'}, {'name': 'EDWLegalPrimaryAgencyAKId', 'data_type': 'integer'}, {'name': 'EDWAgencyRelationshipAKId', 'data_type': 'integer'}, {'name': 'AgencyRelationshipDimHashKey', 'data_type': 'string'}, {'name': 'AgencyCode', 'data_type': 'string'}, {'name': 'LegalPrimaryAgencyCode', 'data_type': 'string'}, {'name': 'AgencyRelationshipEffectiveDate', 'data_type': 'date/time'}, {'name': 'AgencyRelationshipExpirationDate', 'data_type': 'date/time'}, {'name': 'RelationshipType', 'data_type': 'string'}, {'name': 'in_RelatedEDWAgencyAKID', 'data_type': 'integer'}, {'name': 'in_EDWAgencyAKID', 'data_type': 'integer'}]}, 'UPD_OldRecords': {'name': 'UPD_OldRecords', 'task_type': 'Update Strategy', 'transformation_name': 'UPD_OldRecords', 'fields': [{'name': 'AgencyRelationshipDimId', 'data_type': 'integer'}, {'name': 'NewEffectiveToDate', 'data_type': 'date/time'}, {'name': 'CurrentSnapshotFlag', 'data_type': 'string'}, {'name': 'ModifiedDate', 'data_type': 'date/time'}]}, 'SQ_AgencyRelationship': {'name': 'SQ_AgencyRelationship', 'task_type': 'Source Qualifier', 'transformation_name': 'SQ_AgencyRelationship', 'fields': [{'name': 'AgencyRelationshipID', 'data_type': 'integer'}, {'name': 'CurrentSnapshotFlag', 'data_type': 'string'}, {'name': 'AuditID', 'data_type': 'integer'}, {'name': 'EffectiveDate', 'data_type': 'date/time'}, {'name': 'ExpirationDate', 'data_type': 'date/time'}, {'name': 'SourceSystemID', 'data_type': 'string'}, ...

# %%
# Serializing json
json_object = json.dumps(model_basic, indent=4)
 
# Writing to sample.json
with open("model_basic.json", "w") as outfile:
    outfile.write(json_object)
